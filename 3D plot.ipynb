# %%
#pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.8 MB 4.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.8 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.8 MB 3.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 3.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.8 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.8 MB 3.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.8 MB 3.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.8 MB 3.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.8 MB 3.0 MB/s eta 0:00:01
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
x=[10,15,14,15,7]
y=[12,23,14,9,7]
z=[16,17,15,17,8]
t=["new", "old","new", "old", "new"]
fig=px.scatter_3d(x=x,y=y,z=z, color=t)
fig.show()
