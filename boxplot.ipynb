# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=[10,11,12,18,15,16,14,15,19,100]
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16f285ba710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16f285ba990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16f285ba5d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16f285bac10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16f285bad50>],
#  'means': []}

# %%
#seaborn
y=[10,11,12,18,15,16,14,15,19,100]
sns.boxplot(y, palette="Set3", linewidth=2)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_11800\872165704.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y, palette="Set3", linewidth=2)
# <Axes: >
