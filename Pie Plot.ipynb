# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#pie plot

# %%
y=[10,20,34,40]
x=["apple", "samsung","redmi","nothing"]

# %%
plt.pie(y,labels=x,startangle=180, explode=[0,0,0,.2], shadow=True, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1c785062350>,
# ...
#  [Text(-1.050192884287882, -0.3272535802571137, 'apple'),
#   Text(-0.39006502489297706, -1.0285180000151877, 'samsung'),
#   Text(1.0501929701160992, -0.327253304824758, 'redmi'),
#   Text(-0.4609869431724293, 1.2155208917268925, 'nothing')],
#  [Text(-0.5728324823388448, -0.17850195286751655, '9.6%'),
#   Text(-0.21276274085071473, -0.5610098181901023, '19.2%'),
#   Text(0.5728325291542359, -0.17850180263168616, '32.7%'),
#   Text(-0.2836842727214949, 0.7480128564473184, '38.5%')])
